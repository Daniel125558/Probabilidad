# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel125558/Probabilidad/blob/main/UnidadII/practica4__incompleto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 2
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno:Angel Daniel Lopez Higuera
# ### **Programa 4: permutaciones  **

# %%
import math
n=10
k=4
permutaciones = math.factorial(n) / math.factorial(n-k)
print("Numero de maneras de elegir los asistentes: ", int(permutaciones))
# Out:
# Numero de maneras de elegir los asistentes:  5040
