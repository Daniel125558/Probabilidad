# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel125558/Probabilidad/blob/main/Unidad1/practica2__incompleto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno:Angel Daniel Lopez Higuera
# ### **Programa 2: Máximo, minimo, Rango y dispersion de datos**

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
#generamos 100 numeros aleatorios que representan la produccion
#en metrps de tela de 100 dias
fabrica1=[]
for i in range (100):
  numero_aleatorio= round(random.uniform(0,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [78.59, 75.96, 27.97, 29.92, 99.38, 21.48, 64.13, 98.53, 65.05, 76.13, 75.49, 24.26, 59.83, 87.96, 8.54, 34.42, 46.98, 4.47, 21.8, 2.02, 49.04, 12.46, 29.1, 68.28, 68.68, 85.45, 81.96, 48.61, 32.11, 75.01, 51.74, 10.65, 46.35, 43.04, 90.01, 90.5, 50.1, 34.81, 97.65, 89.07, 61.38, 13.57, 15.47, 16.92, 73.24, 76.61, 16.77, 48.32, 76.97, 86.84, 97.31, 41.0, 9.57, 87.58, 86.61, 99.59, 80.36, 28.57, 33.79, 61.69, 77.51, 8.81, 16.48, 9.11, 46.39, 7.98, 3.6, 77.36, 44.86, 90.47, 24.24, 84.86, 90.04, 24.62, 5.98, 5.97, 22.12, 98.1, 47.11, 68.95, 97.01, 76.72, 79.09, 89.51, 55.87, 48.11, 39.5, 75.17, 34.9, 83.9, 29.34, 39.19, 62.49, 21.77, 47.96, 42.61, 34.57, 99.6, 9.53, 67.07]

# %%
fabrica2=[]
for i in range (100):
  numero_aleatorio= round(random.uniform(0,100),2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [43.57, 31.27, 52.86, 54.38, 20.91, 69.12, 52.4, 27.39, 86.43, 48.64, 64.87, 59.22, 52.29, 9.1, 63.84, 89.41, 80.93, 13.91, 83.08, 92.33, 18.97, 86.3, 62.57, 69.66, 67.28, 10.16, 34.92, 91.74, 32.66, 4.85, 21.56, 94.29, 57.92, 54.41, 5.27, 10.91, 12.49, 78.46, 75.63, 35.44, 96.69, 65.41, 80.43, 96.24, 46.83, 83.59, 1.74, 40.06, 13.98, 35.27, 66.05, 19.51, 72.27, 6.46, 40.87, 43.8, 28.1, 88.75, 33.39, 45.47, 3.71, 0.25, 31.44, 48.94, 48.47, 9.7, 2.36, 96.14, 75.02, 75.34, 46.03, 25.81, 36.42, 83.25, 88.87, 14.26, 17.59, 84.33, 0.3, 78.46, 70.13, 25.83, 56.41, 19.27, 33.42, 93.44, 96.85, 8.21, 59.92, 99.03, 17.07, 36.82, 64.05, 26.12, 85.92, 35.86, 17.71, 89.24, 3.91, 53.12]

# %% [markdown]
# # Maxmo, minimo y rango

# %%
maximo1=max(fabrica1)
minimo1=min(fabrica1)
rango1=maximo1-minimo1
media1=mean(fabrica1)
mediana1=median(fabrica1)
moda1=mode(fabrica1)
desviacion_estandar_fabrica1=stdev(fabrica1)

print("Estadistica descriptiva de la fabrica 1 \n", "media =", media1, "\n mediana=", mediana1, "\n moda = ", moda1, "\n maximo", maximo1, "\n minimo = ",minimo1, "\n Rango = ", rango1)
print("desviacion_estandar_fabrica1", desviacion_estandar_fabrica1)
# Out:
# Estadistica descriptiva de la fabrica 1
#  media = 52.5816
#  mediana= 48.825
#  moda =  78.59
#  maximo 99.6
#  minimo =  2.02
#  Rango =  97.58
# desviacion_estandar_fabrica1 29.968729518104247

# %%
maximo2=max(fabrica2)
minimo2=min(fabrica2)
rango2=maximo2-minimo2
media2=mean(fabrica2)
mediana2=median(fabrica2)
moda2=mode(fabrica2)
desviacion_estandar_fabrica2=stdev(fabrica2)

print("Estadistica descriptiva de la fabrica 2 \n", "media =", media2, "\n mediana=", mediana2, "\n moda = ", moda2, "\n maximo", maximo2, "\n minimo = ",minimo2, "\n Rango = ", rango2)
print("desviacion_estandar_fabrica2: ", desviacion_estandar_fabrica2)
# Out:
# Estadistica descriptiva de la fabrica 2
#  media = 48.853699999999996
#  mediana= 48.555
#  moda =  78.46
#  maximo 99.03
#  minimo =  0.25
#  Rango =  98.78
# desviacion_estandar_fabrica2:  29.899641315878387
