# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel125558/Probabilidad/blob/main/Unidad1/Practica1_(incompleto).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno:Angel Daniel Lopez Higuera
# ### **Programa 1: Estadistica basica e Histogramas**

# %%
from statistics import *

# %%
grupoa= [70,70,65,90,100,95,45,80,73,20,100,96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
# la funcion type nos devuelve el tipo de dato de la variable
type(grupoa)
# Out:
# list

# %%
promedio= sum(grupoa)/len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
promedio2= mean(grupoa)
print(promedio2)
