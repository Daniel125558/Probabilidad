# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel125558/Probabilidad/blob/main/Unidad1/practica4__incompleto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno:Angel Daniel Lopez Higuera
# ### **Programa 4: Diagramas de Cajas y bigotes**

# %%
import random
import matplotlib.pyplot as plt
from statistics import median, quantiles

# %%
fabrica1=[]
for i in range (100):
  numero_aleatorio= round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [88.63, 95.57, 76.92, 89.08, 66.72, 78.84, 89.41, 56.59, 72.0, 90.25, 82.25, 78.97, 85.0, 68.29, 71.81, 70.18, 97.2, 53.31, 96.83, 68.64, 50.33, 97.84, 67.97, 54.95, 85.97, 53.27, 89.49, 65.06, 74.89, 63.77, 77.13, 85.28, 86.9, 90.52, 51.54, 73.62, 59.36, 79.69, 54.43, 52.39, 85.05, 88.29, 92.14, 92.84, 51.72, 68.3, 87.01, 81.15, 61.46, 82.36, 70.95, 83.05, 68.16, 60.59, 87.54, 97.35, 87.53, 53.84, 62.85, 64.74, 70.2, 76.95, 73.26, 68.24, 81.09, 87.86, 73.54, 66.94, 74.65, 73.68, 79.23, 70.96, 79.31, 94.62, 99.25, 96.99, 77.43, 90.28, 83.5, 57.65, 80.17, 74.61, 57.17, 99.26, 95.05, 90.09, 55.46, 92.32, 93.18, 67.23, 83.12, 91.88, 66.09, 56.84, 88.11, 93.72, 64.28, 71.02, 66.75, 94.39]

# %%
fabrica2=[]
for i in range (100):
  numero_aleatorio= round(random.uniform(40,93),2)
  fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [71.75, 62.88, 72.86, 50.69, 71.8, 53.37, 66.41, 90.96, 86.64, 90.02, 72.09, 74.61, 51.86, 42.0, 74.32, 75.9, 84.95, 60.63, 78.43, 51.85, 53.65, 43.84, 62.43, 61.46, 50.95, 87.97, 51.85, 71.2, 58.38, 42.38, 68.65, 71.77, 54.81, 62.89, 42.57, 56.31, 83.75, 79.74, 72.39, 91.85, 73.01, 87.33, 76.75, 49.4, 76.12, 69.23, 79.48, 44.93, 40.65, 57.71, 86.42, 74.65, 86.87, 86.72, 61.16, 78.15, 52.21, 67.34, 66.11, 49.8, 64.19, 40.89, 49.91, 70.99, 82.36, 87.02, 60.67, 41.45, 91.38, 77.16, 82.06, 46.99, 43.29, 45.26, 90.88, 92.46, 77.96, 92.53, 82.94, 82.78, 42.29, 75.68, 72.3, 48.17, 79.39, 50.53, 80.65, 45.86, 63.26, 56.08, 88.86, 87.77, 51.21, 55.42, 76.62, 85.95, 65.31, 67.31, 49.93, 41.72]

# %%
plt.boxplot(fabrica1)
plt.ylabel("produccion en mts.")
plt.title("produccion de la fabrica 1 ")
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True,
                     patch_artist=True)
ax1.set_title("produccion de la fabrica 1")
bplot2 = ax2.boxplot(fabrica2,
                     vert=True,
                     patch_artist=True)
ax2.set_title("produccion de la fabrica 2")
plt.tight_layout()
plt.show()

# %%
fabrica1.append(150)
print(fabrica1)
# Out:
# [88.63, 95.57, 76.92, 89.08, 66.72, 78.84, 89.41, 56.59, 72.0, 90.25, 82.25, 78.97, 85.0, 68.29, 71.81, 70.18, 97.2, 53.31, 96.83, 68.64, 50.33, 97.84, 67.97, 54.95, 85.97, 53.27, 89.49, 65.06, 74.89, 63.77, 77.13, 85.28, 86.9, 90.52, 51.54, 73.62, 59.36, 79.69, 54.43, 52.39, 85.05, 88.29, 92.14, 92.84, 51.72, 68.3, 87.01, 81.15, 61.46, 82.36, 70.95, 83.05, 68.16, 60.59, 87.54, 97.35, 87.53, 53.84, 62.85, 64.74, 70.2, 76.95, 73.26, 68.24, 81.09, 87.86, 73.54, 66.94, 74.65, 73.68, 79.23, 70.96, 79.31, 94.62, 99.25, 96.99, 77.43, 90.28, 83.5, 57.65, 80.17, 74.61, 57.17, 99.26, 95.05, 90.09, 55.46, 92.32, 93.18, 67.23, 83.12, 91.88, 66.09, 56.84, 88.11, 93.72, 64.28, 71.02, 66.75, 94.39, 150]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True,
                     patch_artist=True)
ax1.set_title("produccion de la fabrica 1")
bplot2 = ax2.boxplot(fabrica2,
                     vert=True,
                     patch_artist=True)
ax2.set_title("produccion de la fabrica 2")
plt.tight_layout()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9, 5))
bplot1 = ax1.boxplot(fabrica1,
                     vert=True,
                     patch_artist=True)
ax1.set_title("produccion de la fabrica 1")
ax1.set_ylim(30 , 160)
bplot2 = ax2.boxplot(fabrica2,
                     vert=True,
                     patch_artist=True)
ax2.set_title("produccion de la fabrica 2")
ax2.set_ylim(30 , 160)
plt.tight_layout()
plt.show()
