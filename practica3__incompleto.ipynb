# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel125558/Probabilidad/blob/main/practica3__incompleto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 1
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno:Angel Daniel Lopez Higuera
# ### **Programa 3: Tabla de frecuencias y regla de Stirges**

# %%
import random
edades =[]
for i in range (100):
  numero_aleatorio = random.randint(18,70)
  edades.append(numero_aleatorio)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [40, 40, 33, 33, 66, 66, 57, 57, 42, 42, 37, 37, 39, 39, 49, 49, 26, 26, 42, 42, 30, 30, 50, 50, 70, 70, 36, 36, 27, 27, 19, 19, 69, 69, 59, 59, 51, 51, 24, 24, 20, 20, 55, 55, 52, 52, 34, 34, 61, 61, 20, 20, 28, 28, 64, 64, 27, 27, 19, 19, 68, 68, 23, 23, 46, 46, 45, 45, 54, 54, 22, 22, 65, 65, 65, 65, 38, 38, 57, 57, 29, 29, 58, 58, 41, 41, 65, 65, 24, 24, 43, 43, 48, 48, 43, 43, 69, 69, 26, 26, 62, 62, 40, 40, 51, 51, 56, 56, 54, 54, 47, 47, 43, 43, 32, 32, 63, 63, 35, 35, 22, 22, 48, 48, 41, 41, 25, 25, 40, 40, 21, 21, 47, 47, 33, 33, 53, 53, 27, 27, 21, 21, 61, 61, 34, 34, 65, 65, 64, 64, 38, 38, 44, 44, 63, 63, 69, 69, 52, 52, 26, 26, 39, 39, 39, 39, 63, 63, 46, 46, 53, 53, 43, 43, 56, 56, 48, 48, 42, 42, 24, 24, 66, 66, 29, 29, 41, 41, 38, 38, 18, 18, 26, 26, 69, 69, 29, 29, 61, 61]

# %%
import pandas as pd
df= pd.DataFrame(edades, columns=['Edades'])
df.head()
# Out:
#    Edades
# 0      40
# 1      40
# 2      33
# 3      33
# 4      66

# %%
tabla_frecuencias= df['Edades'].value_counts().reset_index()
tabla_frecuencias.columns= ['Edades', 'Frecuencia']
tabla_frecuencias= tabla_frecuencias.sort_values(by='Edades')

print("Tabla de distribucion de Frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de distribucion de Frecuencias:
#     Edades  Frecuencia
# 49      18           2
# 17      19           4
# 30      20           4
# 20      21           4
# 29      22           4
# 42      23           2
# 6       24           6
# 46      25           2
# 1       26           8
# 4       27           6
# 41      28           2
# 11      29           6
# 32      30           2
# 45      32           2
# 15      33           4
# 23      34           4
# 47      35           2
# 37      36           2
# 33      37           2
# 7       38           6
# 8       39           6
# 5       40           6
# 12      41           6
# 9       42           6
# 2       43           8
# 48      44           2
# 40      45           2
# 28      46           4
# 19      47           4
# 13      48           6
# 31      49           2
# 35      50           2
# 25      51           4
# 24      52           4
# 18      53           4
# 27      54           4
# 38      55           2
# ...

# %%
tabla_frecuencias['frec Relativa']= tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edades  Frecuencia  frec Relativa
# 49      18           2           0.02
# 17      19           4           0.04
# 30      20           4           0.04
# 20      21           4           0.04
# 29      22           4           0.04
# 42      23           2           0.02
# 6       24           6           0.06
# 46      25           2           0.02
# 1       26           8           0.08
# 4       27           6           0.06
# 41      28           2           0.02
# 11      29           6           0.06
# 32      30           2           0.02
# 45      32           2           0.02
# 15      33           4           0.04
# 23      34           4           0.04
# 47      35           2           0.02
# 37      36           2           0.02
# 33      37           2           0.02
# 7       38           6           0.06
# 8       39           6           0.06
# 5       40           6           0.06
# 12      41           6           0.06
# 9       42           6           0.06
# ...

# %%
tabla_frecuencias['frec Relativa']= tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edades  Frecuencia  frec Relativa
# 49      18           2            2.0
# 17      19           4            4.0
# 30      20           4            4.0
# 20      21           4            4.0
# 29      22           4            4.0
# 42      23           2            2.0
# 6       24           6            6.0
# 46      25           2            2.0
# 1       26           8            8.0
# 4       27           6            6.0
# 41      28           2            2.0
# 11      29           6            6.0
# 32      30           2            2.0
# 45      32           2            2.0
# 15      33           4            4.0
# 23      34           4            4.0
# 47      35           2            2.0
# 37      36           2            2.0
# 33      37           2            2.0
# 7       38           6            6.0
# 8       39           6            6.0
# 5       40           6            6.0
# 12      41           6            6.0
# 9       42           6            6.0
# ...

# %%
tabla_frecuencias['frec ACUMULADA']= tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edades  Frecuencia  frec Relativa  frec ACUMULADA
# 49      18           2            2.0               2
# 17      19           4            4.0               6
# 30      20           4            4.0              10
# 20      21           4            4.0              14
# 29      22           4            4.0              18
# 42      23           2            2.0              20
# 6       24           6            6.0              26
# 46      25           2            2.0              28
# 1       26           8            8.0              36
# 4       27           6            6.0              42
# 41      28           2            2.0              44
# 11      29           6            6.0              50
# 32      30           2            2.0              52
# 45      32           2            2.0              54
# 15      33           4            4.0              58
# 23      34           4            4.0              62
# ...

# %%
import math

# %%
print(edades)
# Out:
# [40, 40, 33, 33, 66, 66, 57, 57, 42, 42, 37, 37, 39, 39, 49, 49, 26, 26, 42, 42, 30, 30, 50, 50, 70, 70, 36, 36, 27, 27, 19, 19, 69, 69, 59, 59, 51, 51, 24, 24, 20, 20, 55, 55, 52, 52, 34, 34, 61, 61, 20, 20, 28, 28, 64, 64, 27, 27, 19, 19, 68, 68, 23, 23, 46, 46, 45, 45, 54, 54, 22, 22, 65, 65, 65, 65, 38, 38, 57, 57, 29, 29, 58, 58, 41, 41, 65, 65, 24, 24, 43, 43, 48, 48, 43, 43, 69, 69, 26, 26, 62, 62, 40, 40, 51, 51, 56, 56, 54, 54, 47, 47, 43, 43, 32, 32, 63, 63, 35, 35, 22, 22, 48, 48, 41, 41, 25, 25, 40, 40, 21, 21, 47, 47, 33, 33, 53, 53, 27, 27, 21, 21, 61, 61, 34, 34, 65, 65, 64, 64, 38, 38, 44, 44, 63, 63, 69, 69, 52, 52, 26, 26, 39, 39, 39, 39, 63, 63, 46, 46, 53, 53, 43, 43, 56, 56, 48, 48, 42, 42, 24, 24, 66, 66, 29, 29, 41, 41, 38, 38, 18, 18, 26, 26, 69, 69, 29, 29, 61, 61]

# %%
df= pd.DataFrame({'frec Relativa'})
df
# Out:
#                0
# 0  frec Relativa

# %%
n= len(edades)
k= int(1+math.log2(n))
print("valor de n= ", n , "\n Numero de intervalos= ", k)
# Out:
# valor de n=  200
#  Numero de intervalos=  8

# %%
tabla_frecuencias = pd.cut(edades, bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['clase', 'Frec']
tabla_frecuencias = tabla_frecuencias.sort_values(by='clase')
tabla_frecuencias
# Out:
#             clase  Frec
# 0  (17.947, 24.5]    26
# 1    (24.5, 31.0]    26
# 2    (31.0, 37.5]    16
# 3    (37.5, 44.0]    40
# 4    (44.0, 50.5]    20
# 5    (50.5, 57.0]    26
# 6    (57.0, 63.5]    18
# 7    (63.5, 70.0]    28

# %%
tabla_frecuencias= tabla_frecuencias.sort_values(by='clase')
tabla_frecuencias
# Out:
#             clase  Frec
# 0  (17.947, 24.5]    26
# 1    (24.5, 31.0]    26
# 2    (31.0, 37.5]    16
# 3    (37.5, 44.0]    40
# 4    (44.0, 50.5]    20
# 5    (50.5, 57.0]    26
# 6    (57.0, 63.5]    18
# 7    (63.5, 70.0]    28

# %%
tabla_frecuencias['frec Rel']= tabla_frecuencias['Frec']/n
tabla_frecuencias['frec Porc']= tabla_frecuencias['Frec'] / n*100
tabla_frecuencias['frec Ac']= tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['frec Rel Ac']= tabla_frecuencias['frec Rel'].cumsum()
tabla_frecuencias['frec Porc Ac']= tabla_frecuencias['frec Porc'].cumsum()
print(tabla_frecuencias)
# Out:
#             clase  Frec  frec Rel  frec Porc  frec Ac  frec Rel Ac  \
# 0  (17.947, 24.5]    26      0.13       13.0       26         0.13
# 1    (24.5, 31.0]    26      0.13       13.0       52         0.26
# 2    (31.0, 37.5]    16      0.08        8.0       68         0.34
# 3    (37.5, 44.0]    40      0.20       20.0      108         0.54
# 4    (44.0, 50.5]    20      0.10       10.0      128         0.64
# 5    (50.5, 57.0]    26      0.13       13.0      154         0.77
# 6    (57.0, 63.5]    18      0.09        9.0      172         0.86
# 7    (63.5, 70.0]    28      0.14       14.0      200         1.00
#
#    frec Porc Ac
# 0          13.0
# 1          26.0
# 2          34.0
# 3          54.0
# 4          64.0
# 5          77.0
# 6          86.0
# 7         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha=0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
plt.hist(edades, bins=k, alpha=0.5)
plt.title("Histrograma de edades basado en la regla de sturges ")
plt.xlabel("Edades")
plt.ylabel("Frecuencia")
# Out:
# Text(0, 0.5, 'Frecuencia')
