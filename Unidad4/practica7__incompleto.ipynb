# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel125558/Probabilidad/blob/main/Unidad4/practica7__incompleto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 4
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno:Angel Daniel Lopez Higuera
# ### **Programa 7: Distribución Poisson - Seguros de vida**

# %%
from scipy.stats import poisson

# Parámetros de la distribución de Poisson
media_muertes = 5000 * 0.001  # 5000 hombres con una probabilidad de muerte de 0.001

# Número de reclamaciones
x = 4

# Calcular la probabilidad de que la compañía tenga que pagar 4 reclamaciones en un año determinado
probabilidad_4_reclamaciones = poisson.pmf(x, media_muertes)

print("La probabilidad de que la compañía tenga que pagar 4 reclamaciones es:",
      probabilidad_4_reclamaciones)
# Out:
# La probabilidad de que la compañía tenga que pagar 4 reclamaciones es: 0.17546736976785063
