# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel125558/Probabilidad/blob/main/Unidad3/practica6__incompleto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 3
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno:Angel Daniel Lopez Higuera
# ### **Programa 6:  El investigador**

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,6,7,8,9,10])
p=np.array([0.05,0.10,0.20,0.30,0.25,0.10])
print("sua de probabilidades:", np.sum(p))
E= np.sum(x*p)
print("valor esperado e(x):",E)
E2= np.sum((x**2)*p)
var=E2-(E**2)
print("varianza:",var)
std=np.sqrt(var)
print("desviacion estandar:",std)
F=np.cumsum(p)
print("funcion acumulada F(x):",F)

plt.step(x,F, where="post")
plt.scatter(x,F)
plt.xlabel("Numero de celulas anormales(x)")
plt.ylabel("F(x)")
plt.title("funcion de distribucion acumulada")
plt.grid()
plt.show()
# Out:
# sua de probabilidades: 1.0
# valor esperado e(x): 7.9
# varianza: 1.6899999999999906
# desviacion estandar: 1.2999999999999965
# funcion acumulada F(x): [0.05 0.15 0.35 0.65 0.9  1.  ]
