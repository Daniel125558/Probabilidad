# %% [markdown]
# <a href="https://colab.research.google.com/github/Daniel125558/Probabilidad/blob/main/Unidad3/practica4__incompleto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Probabilidad y estadistica
# ## Unidad 3
# ### Facilitador: Jose Gabriel Rodriguez Rivas
# ### Alumno:Angel Daniel Lopez Higuera
# ### **Programa 4: funcion de distribucion acumilada**

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
x=[5,6,7,8,9,10]
p=[0.05,0.10,0.20,0.30,0.25,0.10]

F=np.cumsum(p)
for xi, fi in zip(x,F):
  print(f"F({xi})={fi:.2f}")
plt.step(x, F, where='post')
plt.title("funcion de distribucion acumulada (fda)")
plt.xlabel("calificacion")
plt.ylabel("probabilidad acumulada")
plt.grid(True)
plt.ylim(0,1.05)
plt.show()
# Out:
# E(x) = 7.90
# E(x2) = 64.10
# varianza = 1.69
# desviacion estandar = 1.30
